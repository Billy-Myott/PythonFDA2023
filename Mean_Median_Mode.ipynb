# %% [markdown]
# <a href="https://colab.research.google.com/github/Billy-Myott/PythonFDA2023/blob/main/Mean_Median_Mode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Billy-Myott/PythonFDA2023/main/dataset.csv")

# Calculate the mean, median, and mode for each column
statistics = {}

# Iterate over each column
for column in df.columns:
    # Skip columns that do not contain numerical data
    if df[column].dtype not in [int, float]:
        continue

    # Calculate the mean
    mean = df[column].mean()

    # Calculate the median
    median = df[column].median()

    # Calculate the mode (may have multiple modes)
    mode = df[column].mode()

    # Store the statistics in the dictionary
    statistics[column] = {
        'mean': mean,
        'median': median,
        'mode': mode
    }

# Print the statistics for each column
for column, stats in statistics.items():
    print(f"Column: {column}")
    print(f"Mean: {stats['mean']}")
    print(f"Median: {stats['median']}")
    print(f"Mode: {stats['mode']}")
    print()
# Out:
# Column: Unnamed: 0
# Mean: 56999.5
# Median: 56999.5
# Mode: 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#            ...
# 113995    113995
# 113996    113996
# 113997    113997
# 113998    113998
# 113999    113999
# Name: Unnamed: 0, Length: 114000, dtype: int64
#
# Column: popularity
# Mean: 33.2385350877193
# Median: 35.0
# Mode: 0    0
# Name: popularity, dtype: int64
#
# Column: duration_ms
# Mean: 228029.15311403509
# Median: 212906.0
# Mode: 0    162897
# Name: duration_ms, dtype: int64
#
# Column: danceability
# Mean: 0.5668000657894738
# Median: 0.58
# Mode: 0    0.647
# Name: danceability, dtype: float64
#
# Column: energy
# Mean: 0.6413827583964912
# Median: 0.685
# Mode: 0    0.876
# Name: energy, dtype: float64
#
# Column: key
# Mean: 5.309140350877193
# Median: 5.0
# Mode: 0    7
# Name: key, dtype: int64
#
# Column: loudness
# Mean: -8.258960368421052
# Median: -7.004
# Mode: 0   -5.662
# Name: loudness, dtype: float64
#
# Column: mode
# Mean: 0.6375526315789474
# Median: 1.0
# Mode: 0    1
# Name: mode, dtype: int64
#
# Column: speechiness
# Mean: 0.08465211228070177
# Median: 0.0489
# Mode: 0    0.0323
# Name: speechiness, dtype: float64
#
# Column: acousticness
# Mean: 0.3149100624799999
# Median: 0.169
# Mode: 0    0.995
# Name: acousticness, dtype: float64
#
# Column: instrumentalness
# Mean: 0.15604958922122808
# Median: 4.16e-05
# Mode: 0    0.0
# Name: instrumentalness, dtype: float64
#
# Column: liveness
# Mean: 0.21355283605263162
# Median: 0.132
# Mode: 0    0.108
# Name: liveness, dtype: float64
#
# Column: valence
# Mean: 0.4740682309736842
# Median: 0.464
# Mode: 0    0.961
# Name: valence, dtype: float64
#
# Column: tempo
# Mean: 122.14783728947369
# Median: 122.017
# Mode: 0    0.0
# Name: tempo, dtype: float64
#
# Column: time_signature
# Mean: 3.9040350877192984
# Median: 4.0
# Mode: 0    4
# Name: time_signature, dtype: int64
